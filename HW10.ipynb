# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns

# %%
df = pd.read_csv('titanic.csv')

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# %%
df = df.drop(columns = ['PassengerId', 'Pclass', 'Name', 'SibSp', 'Cabin', 'Fare', 'Ticket'])

# %%
df
# Out:
#      Survived     Sex   Age  Parch Embarked
# 0           0    male  22.0      0        S
# 1           1  female  38.0      0        C
# 2           1  female  26.0      0        S
# 3           1  female  35.0      0        S
# 4           0    male  35.0      0        S
# ..        ...     ...   ...    ...      ...
# 886         0    male  27.0      0        S
# 887         1  female  19.0      0        S
# 888         0  female   NaN      2        S
# 889         1    male  26.0      0        C
# 890         0    male  32.0      0        Q
#
# [891 rows x 5 columns]

# %%
mapping = {'male':0, 'female':1}
df['Sex'] = df['Sex'].map(mapping)

# %%
df
# Out:
#      Survived  Sex   Age  Parch Embarked
# 0           0    0  22.0      0        S
# 1           1    1  38.0      0        C
# 2           1    1  26.0      0        S
# 3           1    1  35.0      0        S
# 4           0    0  35.0      0        S
# ..        ...  ...   ...    ...      ...
# 886         0    0  27.0      0        S
# 887         1    1  19.0      0        S
# 888         0    1   NaN      2        S
# 889         1    0  26.0      0        C
# 890         0    0  32.0      0        Q
#
# [891 rows x 5 columns]

# %%
set(df['Embarked'])
# Out:
# {'C', 'Q', 'S', nan}

# %%
df = df.dropna()

# %%
set(df['Embarked'])
# Out:
# {'C', 'Q', 'S'}

# %%
mapping = {'C':0, 'Q':1, 'S':2}
df['Embarked'] = df['Embarked'].map(mapping)
# Out:
# /var/folders/47/68_3qx9d62z1bs8z4w62gkr00000gn/T/ipykernel_99557/1878876490.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Embarked'] = df['Embarked'].map(mapping)

# %%
df.head()
# Out:
#    Survived  Sex   Age  Parch  Embarked
# 0         0    0  22.0      0         2
# 1         1    1  38.0      0         0
# 2         1    1  26.0      0         2
# 3         1    1  35.0      0         2
# 4         0    0  35.0      0         2

# %%
x = df.iloc[:, 1:]
y = df.iloc[:, 1]

# %%
x
# Out:
#      Sex   Age  Parch  Embarked
# 0      0  22.0      0         2
# 1      1  38.0      0         0
# 2      1  26.0      0         2
# 3      1  35.0      0         2
# 4      0  35.0      0         2
# ..   ...   ...    ...       ...
# 885    1  39.0      5         1
# 886    0  27.0      0         2
# 887    1  19.0      0         2
# 889    0  26.0      0         0
# 890    0  32.0      0         1
#
# [712 rows x 4 columns]

# %%
y
# Out:
# 0      0
# 1      1
# 2      1
# 3      1
# 4      0
#       ..
# 885    1
# 886    0
# 887    1
# 889    0
# 890    0
# Name: Sex, Length: 712, dtype: int64

# %%
x = x.values
y = y.values

# %%
x
# Out:
# array([[ 0., 22.,  0.,  2.],
#        [ 1., 38.,  0.,  0.],
#        [ 1., 26.,  0.,  2.],
#        ...,
#        [ 1., 19.,  0.,  2.],
#        [ 0., 26.,  0.,  0.],
#        [ 0., 32.,  0.,  1.]])

# %%
scaler = StandardScaler()

# %%
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size = 15, random_state = 2025)

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
knn = KNeighborsClassifier()

# %%
knn.fit(X_train, y_train)
# Out:
# KNeighborsClassifier()

# %%
round(np.sum(knn.predict(X_test)==y_test)/len(y_test), 2)
# Out:
# np.float64(0.93)

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rf = RandomForestClassifier()

# %%
rf.fit(X_train, y_train)
# Out:
# RandomForestClassifier()

# %%
round(np.sum(rf.predict(X_test)==y_test)/len(y_test), 2)
# Out:
# np.float64(1.0)

# %%
knn_1 = KNeighborsClassifier(1)
knn_3 = KNeighborsClassifier(3)
knn_5 = KNeighborsClassifier(5)
knn_10 = KNeighborsClassifier(10)
knn_20 = KNeighborsClassifier(20)
rf_1 = RandomForestClassifier(1)
rf_3 = RandomForestClassifier(3)
rf_5 = RandomForestClassifier(5)
rf_10 = RandomForestClassifier(10)
rf_20 = RandomForestClassifier(20)
knn_1.fit(X_train, y_train)
knn_3.fit(X_train, y_train)
knn_5.fit(X_train, y_train)
knn_10.fit(X_train, y_train)
knn_20.fit(X_train, y_train)
rf_1.fit(X_train, y_train)
rf_3.fit(X_train, y_train)
rf_5.fit(X_train, y_train)
rf_10.fit(X_train, y_train)
rf_20.fit(X_train, y_train)
# Out:
# RandomForestClassifier(n_estimators=20)

# %%
print(f'knn_1: {round(np.sum(knn_1.predict(X_test)==y_test)/len(y_test), 2)}')
print(f'knn_3: {round(np.sum(knn_3.predict(X_test)==y_test)/len(y_test), 2)}')
print(f'knn_5: {round(np.sum(knn_5.predict(X_test)==y_test)/len(y_test), 2)}')
print(f'knn_10: {round(np.sum(knn_10.predict(X_test)==y_test)/len(y_test), 2)}')
print(f'knn_20: {round(np.sum(knn_20.predict(X_test)==y_test)/len(y_test), 2)}')
print(f'rf_1: {round(np.sum(rf_1.predict(X_test)==y_test)/len(y_test), 2)}')
print(f'rf_3: {round(np.sum(rf_3.predict(X_test)==y_test)/len(y_test), 2)}')
print(f'rf_5: {round(np.sum(rf_5.predict(X_test)==y_test)/len(y_test), 2)}')
print(f'rf_10: {round(np.sum(rf_10.predict(X_test)==y_test)/len(y_test), 2)}')
print(f'rf_20: {round(np.sum(rf_20.predict(X_test)==y_test)/len(y_test), 2)}')
# Out:
# knn_1: 0.93
# knn_3: 0.87
# knn_5: 0.93
# knn_10: 0.67
# knn_20: 0.53
# rf_1: 1.0
# rf_3: 1.0
# rf_5: 1.0
# rf_10: 1.0
# rf_20: 1.0

# %%
from xgboost import XGBClassifier

# %%
xgb = XGBClassifier()

# %%
df = pd.read_csv('train.csv')

# %%
df.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
df = df.dropna()
df.columns
# Out:
# Index(['Id', 'MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street',
#        'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig',
#        'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType',
#        'HouseStyle', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd',
#        'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType',
#        'MasVnrArea', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual',
#        'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1',
#        'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating',
#        'HeatingQC', 'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF',
#        'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual',
#        'TotRmsAbvGrd', 'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType',
#        'GarageYrBlt', 'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual',
# ...

# %%
from sklearn.model_selection import KFold, cross_val_score

# %%
from sklearn.model_selection import GridSearchCV

# %%
df = pd.read_csv('boston.csv')
df.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296.0
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242.0
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242.0
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222.0
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222.0
#
#    PTRATIO       B  LSTAT  MEDV
# 0     15.3  396.90   4.98  24.0
# 1     17.8  396.90   9.14  21.6
# 2     17.8  392.83   4.03  34.7
# 3     18.7  394.63   2.94  33.4
# 4     18.7  396.90   5.33  36.2

# %%
x = df.iloc[:, :-1]

# %%
y = df.iloc[:, -1]

# %%
x
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0    0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296.0
# 1    0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242.0
# 2    0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242.0
# 3    0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222.0
# 4    0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222.0
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...    ...
# 501  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273.0
# 502  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273.0
# 503  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273.0
# 504  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273.0
# 505  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273.0
#
#      PTRATIO       B  LSTAT
# 0       15.3  396.90   4.98
# 1       17.8  396.90   9.14
# ...

# %%
y
# Out:
# 0      24.0
# 1      21.6
# 2      34.7
# 3      33.4
# 4      36.2
#        ...
# 501    22.4
# 502    20.6
# 503    23.9
# 504    22.0
# 505    11.9
# Name: MEDV, Length: 506, dtype: float64

# %%
x = x.values

# %%
param_grid = {
    'n_estimators': [100, 200, 300],
    'max_depth': [3, 5, 7],
    'learning_rate': [0.01, 0.1, 0.2],
    'subsample': [0.7, 0.8, 1.0],
    'colsample_bytree': [0.7, 0.8, 1.0]
}

# %%
grid_search = GridSearchCV(
    estimator=xgb, 
    param_grid=param_grid, 
    scoring='accuracy',  # Change this metric based on your problem
    cv=5, 
    verbose=1, 
    n_jobs=-1
)

# %%
grid_search.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 243 candidates, totalling 1215 fits
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/numpy/ma/core.py:2846: RuntimeWarning: invalid value encountered in cast
#   _data = np.array(data, dtype=dtype, copy=copy,
# GridSearchCV(cv=5,
#              estimator=XGBClassifier(base_score=None, booster=None,
#                                      callbacks=None, colsample_bylevel=None,
#                                      colsample_bynode=None,
#                                      colsample_bytree=None, device=None,
#                                      early_stopping_rounds=None,
#                                      enable_categorical=False, eval_metric=None,
#                                      feature_types=None, gamma=None,
#                                      grow_policy=None, importance_type=None,
#                                      interaction_constraints=None,
# ...

# %%
grid_search.best_params_
# Out:
# {'colsample_bytree': 0.7,
#  'learning_rate': 0.01,
#  'max_depth': 3,
#  'n_estimators': 100,
#  'subsample': 0.7}

# %%
xgb_best = XGBClassifier(colsample_bytree = 0.7,
  learning_rate = 0.01,
  max_depth= 3,
  n_estimators= 100,
  subsample= 0.7)
